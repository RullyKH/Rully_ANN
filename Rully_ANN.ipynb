# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import classification_report

# %%
df = pd.read_csv(r'C:\Users\ACER\Downloads\car_purchasing.csv', encoding='ISO-8859-1')
df.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %%
df.drop(columns=['customer name', 'customer e-mail', 'country', 'gender'], inplace=True)

# %%
df.head()
# Out:
#          age  annual Salary  credit card debt    net worth  \
# 0  41.851720    62812.09301      11609.380910  238961.2505
# 1  40.870623    66646.89292       9572.957136  530973.9078
# 2  43.152897    53798.55112      11160.355060  638467.1773
# 3  58.271369    79370.03798      14426.164850  548599.0524
# 4  57.313749    59729.15130       5358.712177  560304.0671
#
#    car purchase amount
# 0          35321.45877
# 1          45115.52566
# 2          42925.70921
# 3          67422.36313
# 4          55915.46248

# %%
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  500 non-null    float64
#  1   annual Salary        500 non-null    float64
#  2   credit card debt     500 non-null    float64
#  3   net worth            500 non-null    float64
#  4   car purchase amount  500 non-null    float64
# dtypes: float64(5)
# memory usage: 19.7 KB
# age                    0
# annual Salary          0
# credit card debt       0
# net worth              0
# car purchase amount    0
# dtype: int64

# %%
plt.scatter(df['annual Salary'] , df['credit card debt'])
plt.xlabel('annual Salary')
plt.ylabel('credit card debt')
plt.title('the corr between credit card debt and annual Salary')
# Out:
# Text(0.5, 1.0, 'the corr between credit card debt and annual Salary')

# %%
sns.pairplot(df)

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
scale = MinMaxScaler()
X = scale.fit_transform(X)
y = scale.fit_transform(y.values.reshape(-1, 1))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# %%
#Trying linear regression
lreg = LinearRegression()
lreg.fit(X_train, y_train)
print('Train score', lreg.score(X_train, y_train))
print('Test score', lreg.score(X_test, y_test))
# Out:
# Train score 0.9999999810203092
# Test score 0.9999999817803515

# %%
y_pred = lreg.predict(X_test)

# %%
ann = Sequential([Dense(32, activation="relu"),
                 Dense(1, activation='linear')])

ann.compile(optimizer='adam',
            loss='mean_squared_error',
            metrics=['mean_absolute_error'])


history = ann.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 0.4627 - mean_absolute_error: 0.6564 - val_loss: 0.3938 - val_mean_absolute_error: 0.5883
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3424 - mean_absolute_error: 0.5589 - val_loss: 0.2814 - val_mean_absolute_error: 0.4890
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2377 - mean_absolute_error: 0.4593 - val_loss: 0.1953 - val_mean_absolute_error: 0.3968
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1643 - mean_absolute_error: 0.3669 - val_loss: 0.1295 - val_mean_absolute_error: 0.3104
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1020 - mean_absolute_error: 0.2811 - val_loss: 0.0814 - val_mean_absolute_error: 0.2353
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0631 - mean_absolute_error: 0.2116 - val_loss: 0.0489 - val_mean_absolute_error: 0.1731
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0416 - mean_absolute_error: 0.1651 - val_loss: 0.0310 - val_mean_absolute_error: 0.1408
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0246 - mean_absolute_error: 0.1236 - val_loss: 0.0245 - val_mean_absolute_error: 0.1296
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0185 - mean_absolute_error: 0.1065 - val_loss: 0.0227 - val_mean_absolute_error: 0.1265
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0177 - mean_absolute_error: 0.1043 - val_loss: 0.0208 - val_mean_absolute_error: 0.1216
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0168 - mean_absolute_error: 0.1034 - val_loss: 0.0185 - val_mean_absolute_error: 0.1132
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0129 - mean_absolute_error: 0.0874 - val_loss: 0.0166 - val_mean_absolute_error: 0.1051
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0131 - mean_absolute_error: 0.0877 - val_loss: 0.0148 - val_mean_absolute_error: 0.0992
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0110 - mean_absolute_error: 0.0788 - val_loss: 0.0132 - val_mean_absolute_error: 0.0947
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0104 - mean_absolute_error: 0.0778 - val_loss: 0.0119 - val_mean_absolute_error: 0.0911
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0092 - mean_absolute_error: 0.0727 - val_loss: 0.0110 - val_mean_absolute_error: 0.0887
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0077 - mean_absolute_error: 0.0673 - val_loss: 0.0102 - val_mean_absolute_error: 0.0858
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0084 - mean_absolute_error: 0.0685 - val_loss: 0.0096 - val_mean_absolute_error: 0.0835
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0065 - mean_absolute_error: 0.0621 - val_loss: 0.0090 - val_mean_absolute_error: 0.0806
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0071 - mean_absolute_error: 0.0655 - val_loss: 0.0085 - val_mean_absolute_error: 0.0785
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0065 - mean_absolute_error: 0.0639 - val_loss: 0.0082 - val_mean_absolute_error: 0.0766
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0066 - mean_absolute_error: 0.0630 - val_loss: 0.0078 - val_mean_absolute_error: 0.0747
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0063 - mean_absolute_error: 0.0622 - val_loss: 0.0074 - val_mean_absolute_error: 0.0723
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0059 - mean_absolute_error: 0.0605 - val_loss: 0.0071 - val_mean_absolute_error: 0.0706
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0052 - mean_absolute_error: 0.0562 - val_loss: 0.0069 - val_mean_absolute_error: 0.0695
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0058 - mean_absolute_error: 0.0587 - val_loss: 0.0065 - val_mean_absolute_error: 0.0673
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0056 - mean_absolute_error: 0.0575 - val_loss: 0.0063 - val_mean_absolute_error: 0.0661
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0044 - mean_absolute_error: 0.0519 - val_loss: 0.0060 - val_mean_absolute_error: 0.0645
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0048 - mean_absolute_error: 0.0540 - val_loss: 0.0057 - val_mean_absolute_error: 0.0628
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0045 - mean_absolute_error: 0.0530 - val_loss: 0.0055 - val_mean_absolute_error: 0.0614
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0041 - mean_absolute_error: 0.0506 - val_loss: 0.0053 - val_mean_absolute_error: 0.0604
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0042 - mean_absolute_error: 0.0506 - val_loss: 0.0050 - val_mean_absolute_error: 0.0591
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0041 - mean_absolute_error: 0.0511 - val_loss: 0.0048 - val_mean_absolute_error: 0.0575
# Epoch 34/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0036 - mean_absolute_error: 0.0470 - val_loss: 0.0046 - val_mean_absolute_error: 0.0564
# Epoch 35/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0037 - mean_absolute_error: 0.0490 - val_loss: 0.0043 - val_mean_absolute_error: 0.0551
# Epoch 36/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0032 - mean_absolute_error: 0.0458 - val_loss: 0.0042 - val_mean_absolute_error: 0.0540
# Epoch 37/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0029 - mean_absolute_error: 0.0424 - val_loss: 0.0039 - val_mean_absolute_error: 0.0524
# Epoch 38/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0029 - mean_absolute_error: 0.0430 - val_loss: 0.0038 - val_mean_absolute_error: 0.0517
# Epoch 39/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0028 - mean_absolute_error: 0.0410 - val_loss: 0.0036 - val_mean_absolute_error: 0.0506
# Epoch 40/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0028 - mean_absolute_error: 0.0429 - val_loss: 0.0034 - val_mean_absolute_error: 0.0492
# Epoch 41/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0024 - mean_absolute_error: 0.0394 - val_loss: 0.0032 - val_mean_absolute_error: 0.0481
# Epoch 42/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - mean_absolute_error: 0.0408 - val_loss: 0.0031 - val_mean_absolute_error: 0.0468
# Epoch 43/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0024 - mean_absolute_error: 0.0382 - val_loss: 0.0029 - val_mean_absolute_error: 0.0458
# Epoch 44/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0021 - mean_absolute_error: 0.0366 - val_loss: 0.0027 - val_mean_absolute_error: 0.0443
# Epoch 45/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0360 - val_loss: 0.0026 - val_mean_absolute_error: 0.0432
# Epoch 46/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0022 - mean_absolute_error: 0.0373 - val_loss: 0.0024 - val_mean_absolute_error: 0.0415
# Epoch 47/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0019 - mean_absolute_error: 0.0344 - val_loss: 0.0024 - val_mean_absolute_error: 0.0412
# Epoch 48/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0021 - mean_absolute_error: 0.0361 - val_loss: 0.0022 - val_mean_absolute_error: 0.0394
# Epoch 49/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0336 - val_loss: 0.0020 - val_mean_absolute_error: 0.0382
# Epoch 50/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0018 - mean_absolute_error: 0.0339 - val_loss: 0.0019 - val_mean_absolute_error: 0.0370

# %%
tr_acc = history.history['mean_absolute_error']
tr_loss = history.history['loss']
val_acc = history.history['val_mean_absolute_error']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmin(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %%
ann_y_pred = ann.predict(X_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step

# %%
r2 = r2_score(y_test, y_pred)
print('R2 score:', r2)
# Out:
# R2 score: 0.9999999817803515

# %%
ann.evaluate(X_test, y_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015 - mean_absolute_error: 0.0316
# [0.0014508927706629038, 0.031179044395685196]

# %%
input_data = np.array([[40, 70000.50, 9550, 534000]])

predictions = ann.predict(input_data)

print(predictions)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# [[88462.69]]

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, label='Linear Regression')
plt.scatter(y_test, ann_y_pred, label='ANN')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='gray')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Predicted vs. Actual Values')
plt.legend()
plt.show()

# %%
threshold = 0.5
y_pred_binary = (y_pred > threshold).astype(int)
print(classification_report(y_test > 0.5, y_pred_binary))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00        49
#         True       1.00      1.00      1.00        51
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100
